# %%
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_feather('../1_Data_Extraction/Data/Metadata_Only/dicom_df_0.feather')
df2 = pd.read_feather('../1_Data_Extraction/Data/Metadata_Only/dicom_df_1.feather')
df3 = pd.read_feather('../1_Data_Extraction/Data/Metadata_Only/dicom_df_2.feather')
df4 = pd.read_feather('../1_Data_Extraction/Data/Metadata_Only/dicom_df_3.feather')
df5 = pd.read_feather('../1_Data_Extraction/Data/Metadata_Only/dicom_df_4.feather')
df6 = pd.read_feather('../1_Data_Extraction/Data/Metadata_Only/dicom_df_5.feather')
df7 = pd.read_feather('../1_Data_Extraction/Data/Metadata_Only/dicom_df_6.feather')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
df.head()
# Out:
#                        Dicomdir        PatientId  \
# 0  ..\..\Scans\2022-01\DICOMDIR    ANONYM-XT8UJZ
# 1  ..\..\Scans\2022-01\DICOMDIR  ANONYM-XT8UJZ_1
# 2  ..\..\Scans\2022-01\DICOMDIR  ANONYM-XT8UJZ_2
# 3  ..\..\Scans\2022-01\DICOMDIR  ANONYM-XT8UJZ_3
# 4  ..\..\Scans\2022-01\DICOMDIR  ANONYM-XT8UJZ_3
#
#                                              StudyId  \
# 0  1.2.40.0.13.1.31351380426905905351292839561978...
# 1  1.2.40.0.13.1.17673763456969116914244798980205...
# 2  1.2.40.0.13.1.16621219697005344268574789979711...
# 3  1.2.40.0.13.1.16932927470742447813201714735294...
# 4  1.2.40.0.13.1.29987579509307136339818887016894...
#
#                                             SeriesId  AccessionNumber  \
# 0  1.2.40.0.13.1.70506743092902795655309425996746...  GLKQKZDGQZGOZJX
# 1  1.2.40.0.13.1.22199141000052275677980158947820...  QQCKBCDCAIJNUQI
# 2  1.2.40.0.13.1.79080220071392034037718776900243...  PPCTFYIKTTTMOHC
# 3  1.2.40.0.13.1.44600102249142374796035333831945...  KTJTLMCRRPPUONF
# 4  1.2.40.0.13.1.33620446475559136671173278433456...  KTJTLMCRRPPUONF
#
#   AcquisitionDate AcquisitionDateTime  AcquisitionNumber AcquisitionTime  \
# 0        20210610          151639.869                  2      151639.869
# 1        20190221          184011.010                  2      184011.000
# 2        20180314          233423.247                  2      233423.247
# 3        20211012          124143.010                  1      124143.000
# 4        20211012          125518.010                  1      125518.000
#
#   AdmittingDiagnosesDescription  ...  OverlayColumns  OverlayData  \
# 0                                ...             NaN          NaN
# 1                                ...             NaN          NaN
# 2                                ...             NaN          NaN
# 3                                ...             NaN          NaN
# 4                                ...             NaN          NaN
#
#   OverlayDescription OverlayOrigin OverlayRows OverlayType  PatientComments  \
# 0                NaN           NaN         NaN         NaN             None
# 1                NaN           NaN         NaN         NaN             None
# 2                NaN           NaN         NaN         NaN             None
# 3                NaN           NaN         NaN         NaN             None
# 4                NaN           NaN         NaN         NaN             None
#
#   NameOfPhysiciansReadingStudy  EthnicGroup PatientState
# 0                         None         None         None
# 1                         None         None         None
# 2                         None         None         None
# 3                         None         None         None
# 4                         None         None         None
#
# [5 rows x 149 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 149 entries, Dicomdir to PatientState
# dtypes: float64(39), int64(14), object(96)
# memory usage: 116.5+ KB

# %%
df_small = df[["PatientId","PatientWeight","PatientSize","PatientAge","PatientSex", "BodyPartExamined", "ProcedureCodeSequence.CodeMeaning","Rows","Columns","SliceCount","PixelSpacing","SliceThickness"]]
df_small
# Out:
#              PatientId  PatientWeight  PatientSize PatientAge PatientSex  \
# 0        ANONYM-XT8UJZ           80.0         1.81       064Y          M
# 1      ANONYM-XT8UJZ_1           73.0         1.71       056Y          M
# 2      ANONYM-XT8UJZ_2           43.0         1.63       019Y          F
# 3      ANONYM-XT8UJZ_3           74.0         1.63       077Y          F
# 4      ANONYM-XT8UJZ_3           74.0         1.63       077Y          F
# ..                 ...            ...          ...        ...        ...
# 678  ANONYM-BI33HV_438           50.0         1.65       068Y          M
# 679  ANONYM-BI33HV_439           68.0         1.80       075Y          M
# 680  ANONYM-BI33HV_440           64.0         1.58       076Y          F
# 681  ANONYM-BI33HV_441           69.0         1.78       080Y          M
# 682  ANONYM-BI33HV_442           95.0         1.73       072Y          M
#
#     BodyPartExamined ProcedureCodeSequence.CodeMeaning  Rows  Columns  \
# 0            ABDOMEN        PET-CT.F18 FDG .Ganzkörper   512      512
# 1          WHOLEBODY             PET-CT.F18 FDG .Stamm   512      512
# 2            ABDOMEN        PET-CT.F18 FDG .Kopf/Stamm   512      512
# 3               HEAD              PET-CT.F18 FDG .Hirn   512      512
# 4          WHOLEBODY             PET-CT.F18 FDG .Stamm   512      512
# ..               ...                               ...   ...      ...
# 678        WHOLEBODY             PET-CT.F18 FDG .Stamm   512      512
# 679          ABDOMEN        PET-CT.F18 FDG .Kopf/Stamm   512      512
# 680        WHOLEBODY             PET-CT.F18 FDG .Stamm   512      512
# 681          ABDOMEN            PET-CT.Ga68 PSMA.Stamm   512      512
# 682        WHOLEBODY            PET-CT.Ga68 PSMA.Stamm   512      512
#
#      SliceCount            PixelSpacing  SliceThickness
# 0           487  [0.9765625, 0.9765625]             4.0
# 1           567    [1.171875, 1.171875]             3.0
# 2           323  [0.9765625, 0.9765625]             3.0
# 3           119    [1.171875, 1.171875]             3.0
# 4           567    [1.171875, 1.171875]             3.0
# ..          ...                     ...             ...
# 678         623    [1.171875, 1.171875]             3.0
# 679         323  [0.9765625, 0.9765625]             3.0
# 680         511    [1.171875, 1.171875]             3.0
# 681         293  [0.9765625, 0.9765625]             3.0
# 682         623    [1.171875, 1.171875]             3.0
#
# [683 rows x 12 columns]

# %%
df_small["PatientAge"].fillna("-1", inplace=True)
# Out:
# C:\Users\minem\AppData\Local\Temp\ipykernel_29220\3062277607.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_small["PatientAge"].fillna("-1", inplace=True)
# C:\Users\minem\AppData\Local\Temp\ipykernel_29220\3062277607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small["PatientAge"].fillna("-1", inplace=True)

# %%
df_small["PatientAge"] = df_small["PatientAge"].str.replace('Y', '').astype(int)
# Out:
# C:\Users\minem\AppData\Local\Temp\ipykernel_29220\1579402160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small["PatientAge"] = df_small["PatientAge"].str.replace('Y', '').astype(int)

# %%
df_small["BodyPart"] = df_small["ProcedureCodeSequence.CodeMeaning"].str.split(".", expand=True)[2]
# Out:
# C:\Users\minem\AppData\Local\Temp\ipykernel_29220\2801913073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small["BodyPart"] = df_small["ProcedureCodeSequence.CodeMeaning"].str.split(".", expand=True)[2]

# %%
df_small.describe()
# Out:
#        PatientWeight  PatientSize  PatientAge   Rows  Columns   SliceCount  \
# count     683.000000   683.000000  683.000000  683.0    683.0   683.000000
# mean       75.665637     1.712972   66.070278  512.0    512.0   441.325037
# std        18.519663     0.109910   13.292482    0.0      0.0   177.152037
# min         1.000000     1.000000   -1.000000  512.0    512.0    12.000000
# 25%        64.500000     1.655000   59.000000  512.0    512.0   293.000000
# 50%        74.000000     1.720000   68.000000  512.0    512.0   465.000000
# 75%        86.000000     1.780000   77.000000  512.0    512.0   568.000000
# max       160.000000     2.000000   90.000000  512.0    512.0  1015.000000
#
#        SliceThickness
# count      683.000000
# mean         3.108346
# std          0.372206
# min          1.500000
# 25%          3.000000
# 50%          3.000000
# 75%          3.000000
# max          5.000000

# %%
# Distribution of Male/female
df_small['PatientSex'].value_counts()
# Out:
# PatientSex
# M    438
# F    239
# O      6
# Name: count, dtype: int64

# %%
# Distribution of Age
df_small['PatientAge'].value_counts()
# Out:
# PatientAge
#  80    92
#  67    31
#  68    29
#  66    25
#  59    23
#  77    22
#  74    22
#  76    21
#  72    20
#  75    20
#  85    20
#  60    19
#  71    18
#  64    18
#  79    18
#  57    18
#  73    17
#  69    17
#  62    16
#  78    16
#  56    15
#  70    14
#  55    14
#  58    13
#  61    13
#  54    12
#  65    12
#  63    11
#  51     8
#  53     7
#  50     7
#  52     7
#  49     6
#  44     6
#  43     5
#  90     4
#  40     4
#  47     4
#  38     4
#  25     3
#  36     3
#  41     3
#  19     3
#  35     2
#  48     2
#  23     2
#  46     2
#  30     2
#  45     2
#  16     1
#  9      1
# -1      1
#  31     1
#  34     1
#  17     1
#  37     1
#  28     1
#  42     1
#  39     1
#  27     1
# Name: count, dtype: int64

# %%
# Get all lines where BodyPart is Ganzkörper and SliceCount is greater than 600
df_small[(df_small['BodyPart'] == 'Ganzkörper') & (df_small['SliceCount'] > 600)]
# Out:
#              PatientId  PatientWeight  PatientSize  PatientAge PatientSex  \
# 161  ANONYM-XT8UJZ_154           68.0         1.68          80          F
# 164  ANONYM-XT8UJZ_157           61.0         1.78          50          F
# 202  ANONYM-XT8UJZ_195           80.0         1.56          67          F
# 250   ANONYM-BI33HV_18           75.0         1.60          63          F
# 274   ANONYM-BI33HV_42           60.0         1.68          65          F
# 316   ANONYM-BI33HV_84           82.0         1.75          60          M
# 363  ANONYM-BI33HV_129           60.0         1.62          51          F
# 465  ANONYM-BI33HV_231           95.0         1.74          50          M
# 472  ANONYM-BI33HV_238           71.0         1.70          80          M
# 490  ANONYM-BI33HV_256           78.0         1.85          72          M
# 511  ANONYM-BI33HV_275           53.0         1.57          60          F
# 584  ANONYM-BI33HV_347           76.0         1.75          69          M
# 655  ANONYM-BI33HV_415           54.0         1.64          66          F
#
#     BodyPartExamined ProcedureCodeSequence.CodeMeaning  Rows  Columns  \
# 161        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 164        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 202        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 250        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 274        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 316        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 363        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 465        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 472        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 490        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 511        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 584        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
# 655        WHOLEBODY        PET-CT.F18 FDG .Ganzkörper   512      512
#
#      SliceCount          PixelSpacing  SliceThickness    BodyPart
# 161         847  [1.171875, 1.171875]             4.0  Ganzkörper
# 164         845  [1.171875, 1.171875]             4.0  Ganzkörper
# 202         803  [1.171875, 1.171875]             4.0  Ganzkörper
# 250         845  [1.171875, 1.171875]             4.0  Ganzkörper
# 274         845  [1.171875, 1.171875]             4.0  Ganzkörper
# 316         929  [1.171875, 1.171875]             4.0  Ganzkörper
# 363         845  [1.171875, 1.171875]             4.0  Ganzkörper
# 465         886  [1.171875, 1.171875]             4.0  Ganzkörper
# 472         888  [1.171875, 1.171875]             4.0  Ganzkörper
# 490         887  [1.171875, 1.171875]             4.0  Ganzkörper
# 511         803  [1.171875, 1.171875]             4.0  Ganzkörper
# 584         845  [1.171875, 1.171875]             4.0  Ganzkörper
# 655         846  [1.171875, 1.171875]             4.0  Ganzkörper

# %%
# Get all lines where BodyPart is Herz
df_small[df_small['BodyPart'] == 'Herz']
# Out:
#              PatientId  PatientWeight  PatientSize  PatientAge PatientSex  \
# 31    ANONYM-XT8UJZ_30           72.0         1.76          68          M
# 99    ANONYM-XT8UJZ_94           78.0         1.80          76          M
# 129  ANONYM-XT8UJZ_123           50.0         1.60          80          M
#
#     BodyPartExamined ProcedureCodeSequence.CodeMeaning  Rows  Columns  \
# 31             HEART              PET-CT.F18 FDG .Herz   512      512
# 99             HEART              PET-CT.F18 FDG .Herz   512      512
# 129            HEART              PET-CT.F18 FDG .Herz   512      512
#
#      SliceCount          PixelSpacing  SliceThickness BodyPart
# 31          119  [1.171875, 1.171875]             3.0     Herz
# 99          119  [1.171875, 1.171875]             3.0     Herz
# 129         119  [1.171875, 1.171875]             3.0     Herz

# %%
import matplotlib.pyplot as plt
import seaborn as sns
 
# Distribution of Patient Age
plt.figure(figsize=(15, 6))
sns.histplot(df_small['PatientAge'], kde=True)
plt.title('Distribution of Patient Age')
plt.xlabel('Age (years)')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()
 
# Distribution of Patient Weight
plt.figure(figsize=(15, 6))
sns.histplot(df_small['PatientWeight'], kde=True)
plt.title('Distribution of Patient Weight')
plt.xlabel('Weight (kg)')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()
 
# Distribution of Patient Size
plt.figure(figsize=(15, 6))
sns.histplot(df_small['PatientSize'], kde=True)
plt.title('Distribution of Patient Size')
plt.xlabel('Size (m)')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()
 
# SliceCount by BodyPartExamined
plt.figure(figsize=(18, 8))
sns.boxplot(x='BodyPartExamined', y='SliceCount', data=df_small)
plt.title('Slice Count by Body Part Examined')
plt.xlabel('Body Part Examined')
plt.xticks(rotation=90)
plt.ylabel('Slice Count')
plt.show()

# BodyPart distribution
plt.figure(figsize=(15, 6))
sns.countplot(x='BodyPart', data=df_small)
plt.title('Distribution of Body Part')
plt.xlabel('Body Part')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()

# SliceCount by BodyPart
plt.figure(figsize=(18, 8))
sns.boxplot(x='BodyPart', y='SliceCount', data=df_small)
plt.title('Slice Count by Body Part')
plt.xlabel('Body Part')
plt.xticks(rotation=90)
plt.ylabel('Slice Count')
plt.show()
 
# SliceThickness distribution
plt.figure(figsize=(15, 6))
sns.histplot(df_small['SliceThickness'], kde=True)
plt.title('Distribution of Slice Thickness')
plt.xlabel('Slice Thickness (mm)')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\minem\miniconda3\envs\R&D\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\minem\miniconda3\envs\R&D\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\minem\miniconda3\envs\R&D\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\minem\miniconda3\envs\R&D\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
