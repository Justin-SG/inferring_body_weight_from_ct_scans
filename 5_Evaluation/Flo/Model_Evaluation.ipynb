# %%
import pandas as pd

# %%
# Load the data
df = pd.read_csv('model_statistics.csv')
df
# Out:
#   model_name                        dataset_name  train_loss   val_loss  \
# 0   resnet18                     coronal_scaling    6.994072   5.794622
# 1   resnet18                    sagittal_scaling    8.575839  89.526956
# 2   resnet18                     coronal_scaling    6.136872   6.739621
# 3   resnet18                    sagittal_scaling    6.937764   7.357553
# 4   resnet18     axial_spacing_thickness_scaling    6.752290  12.519956
# 5   resnet18   coronal_spacing_thickness_scaling    8.360463  35.890387
# 6   resnet18  sagittal_spacing_thickness_scaling    5.499034  12.314031
#
#    epochs_trained  with_scaling_factor  multiplied_scaling_factor  \
# 0              10                 True                      False
# 1               5                 True                      False
# 2              10                 True                       True
# 3              10                 True                       True
# ...
