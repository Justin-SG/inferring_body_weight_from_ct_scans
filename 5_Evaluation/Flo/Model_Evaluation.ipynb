# %%
import pandas as pd

# %% [markdown]
# model_stats = \
# [
#     {
#         "model_name": "resnet18",
#         "dataset_name": "axial",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 4.3094,
#         "val_loss mean_absolute_error": 6.8288,
#         "max_absolute_error": 37.3711,
#         "epochs_trained": 10,
#         "training_time (seconds)": 16067.
#     },
#     {
#         "model_name": "resnet50",
#         "dataset_name": "axial",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 4.5872,
#         "val_loss mean_absolute_error": 5.9688,
#         "max_absolute_error": 35.8508,
#         "epochs_trained": 10,
#         "training_time (seconds)": 14791.
#     },
#     {
#         "model_name": "vit_b_16",
#         "dataset_name": "axial",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 7.7868,
#         "val_loss mean_absolute_error": 6.8818,
#         "max_absolute_error": 33.1640,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15275.
#     },
#     {
#         "model_name": "vit_b_32",
#         "dataset_name": "axial",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 6.8786,
#         "val_loss mean_absolute_error": 7.0116,
#         "max_absolute_error": 33.0049,
#         "epochs_trained": 10,
#         "training_time (seconds)": 14293.
#     },{
#         "model_name": "resnet18",
#         "dataset_name": "coronal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 4.9607,
#         "val_loss mean_absolute_error": 4.5564,
#         "max_absolute_error": 27.9759,
#         "epochs_trained": 10,
#         "training_time (seconds)": 14608.
#     },
#     {
#         "model_name": "resnet50",
#         "dataset_name": "coronal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 4.5081,
#         "val_loss mean_absolute_error": 4.8340,
#         "max_absolute_error": 35.8572,
#         "epochs_trained": 10,
#         "training_time (seconds)": 14625.
#     },
#     {
#         "model_name": "vit_b_16",
#         "dataset_name": "coronal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 8.2549,
#         "val_loss mean_absolute_error": 7.4156,
#         "max_absolute_error": 38.9660,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15352.
#     },
#     {
#         "model_name": "vit_b_32",
#         "dataset_name": "coronal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 8.6093,
#         "val_loss mean_absolute_error": 7.5051,
#         "max_absolute_error": 38.7023,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15637.
#     },
#     {
#         "model_name": "resnet18",
#         "dataset_name": "sagittal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 4.3687,
#         "val_loss mean_absolute_error": 7.9907,
#         "max_absolute_error": 29.2464,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15551.
#     },
#     {
#         "model_name": "resnet50",
#         "dataset_name": "sagittal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 4.6426,
#         "val_loss mean_absolute_error": 12.1377,
#         "max_absolute_error": 42.6397,
#         "epochs_trained": 10,
#         "training_time (seconds)": 14846.
#     },
#     {
#         "model_name": "vit_b_16",
#         "dataset_name": "sagittal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 7.7205,
#         "val_loss mean_absolute_error": 7.5264,
#         "max_absolute_error": 36.2783,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15159.
#     },
#     {
#         "model_name": "vit_b_32",
#         "dataset_name": "sagittal",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": False,
#         "multiplied_scaling_factor": False,
#         "additional_params": None,
#         "train_loss mean_absolute_error": 7.95,
#         "val_loss mean_absolute_error": 8.8144,
#         "max_absolute_error": 35.7525,
#         "epochs_trained": 10,
#         "training_time (seconds)": 14263.
#     },
#     {
#         "model_name": "resnet18",
#         "dataset_name": "coronal_scaling",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": True,
#         "multiplied_scaling_factor": False,
#         "additional_params": ['scaling_factor'],
#         "train_loss mean_absolute_error": 5.4602,
#         "val_loss mean_absolute_error": 7.002,
#         "max_absolute_error": 44.7177,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15352.
#     },
#     {
#         "model_name": "resnet50",
#         "dataset_name": "coronal_scaling",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": True,
#         "multiplied_scaling_factor": False,
#         "additional_params": ['scaling_factor'],
#         "train_loss mean_absolute_error": 5.8238,
#         "val_loss mean_absolute_error": 7.9350,
#         "max_absolute_error": 32.2683,
#         "epochs_trained": 8,
#         "training_time (seconds)": 11925.
#     },
#     {
#         "model_name": "vit_b_16",
#         "dataset_name": "coronal_scaling",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": True,
#         "multiplied_scaling_factor": False,
#         "additional_params": ['scaling_factor'],
#         "train_loss mean_absolute_error": 7.5837,
#         "val_loss mean_absolute_error": 6.8591,
#         "max_absolute_error": 42.6103,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15826.
#     },
#     {
#         "model_name": "vit_b_32",
#         "dataset_name": "coronal_scaling",
#         "query": 'BodyPart == "Stamm"',
#         "with_scaling_factor": True,
#         "multiplied_scaling_factor": False,
#         "additional_params": ['scaling_factor'],
#         "train_loss mean_absolute_error": 8.4595,
#         "val_loss mean_absolute_error": 7.2868,
#         "max_absolute_error": 42.1269,
#         "epochs_trained": 10,
#         "training_time (seconds)": 15725.
#     }
# ]

# %% [markdown]
# # Load the data
# df = pd.DataFrame(model_stats)
# df

# %% [markdown]
# # Save the data
# df.to_csv('model_statistics.csv', index=False)

# %%
statistics = pd.read_csv('model_statistics.csv')
statistics
# Out:
#    model_name                        dataset_name                query  \
# 0    resnet18                               axial  BodyPart == "Stamm"
# 1    resnet50                               axial  BodyPart == "Stamm"
# 2    vit_b_16                               axial  BodyPart == "Stamm"
# 3    vit_b_32                               axial  BodyPart == "Stamm"
# 4    resnet18                             coronal  BodyPart == "Stamm"
# 5    resnet50                             coronal  BodyPart == "Stamm"
# 6    vit_b_16                             coronal  BodyPart == "Stamm"
# 7    vit_b_32                             coronal  BodyPart == "Stamm"
# 8    resnet18                            sagittal  BodyPart == "Stamm"
# 9    resnet50                            sagittal  BodyPart == "Stamm"
# 10   vit_b_16                            sagittal  BodyPart == "Stamm"
# 11   vit_b_32                            sagittal  BodyPart == "Stamm"
# ...

# %%
# remove all duplicated rows
statistics = statistics.drop_duplicates()
statistics
# Out:
#     model_name                        dataset_name                query  \
# 0     resnet18                               axial  BodyPart == "Stamm"
# 1     resnet50                               axial  BodyPart == "Stamm"
# 2     vit_b_16                               axial  BodyPart == "Stamm"
# 3     vit_b_32                               axial  BodyPart == "Stamm"
# 4     resnet18                             coronal  BodyPart == "Stamm"
# 5     resnet50                             coronal  BodyPart == "Stamm"
# 6     vit_b_16                             coronal  BodyPart == "Stamm"
# 7     vit_b_32                             coronal  BodyPart == "Stamm"
# 8     resnet18                            sagittal  BodyPart == "Stamm"
# 9     resnet50                            sagittal  BodyPart == "Stamm"
# 10    vit_b_16                            sagittal  BodyPart == "Stamm"
# 11    vit_b_32                            sagittal  BodyPart == "Stamm"
# ...

# %%
# plot models/validation loss
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
plt.figure(figsize=(15, 10))
sns.barplot(x='model_name', y='val_loss mean_absolute_error', hue='dataset_name', data=statistics)
plt.title('Validation Loss for Different Models')
plt.show()

# %%
# multiplied scaling vs non-multiplied scaling
plt.figure(figsize=(15, 10))
sns.barplot(x='model_name', y='val_loss mean_absolute_error', hue='multiplied_scaling_factor', data=statistics)
plt.title('Validation Loss for Different Models')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 # multiplied scaling vs non-multiplied scaling
#       2 plt.figure(figsize=(15, 10))
# ----> 3 sns.barplot(x='model_name', y='val_loss mean_absolute_error', hue='multiplied_scaling_factor', data=statistics)
#       4 plt.title('Validation Loss for Different Models')
#       5 plt.show()
#
# File ~\miniconda3\envs\R&D\Lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File ~\miniconda3\envs\R&D\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
# ...
